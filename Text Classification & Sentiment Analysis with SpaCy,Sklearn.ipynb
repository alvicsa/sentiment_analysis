# %% [markdown]
# ### Text Classification With Machine Learning and SpaCy
# + Text categorization / text classification is the task of assigning predefined categories to documents.
# + Sentiment Analysis
# + Multilabel classification
# + + DataSet source http://archive.ics.uci.edu/ml/datasets/Sentiment+Labelled+Sentences
#
# ##### Aim is to classify reviews into positive or negative review

# %%
# Load EDA packages
import pandas as pd

# %%
# Load our dataset
# df_yelp = pd.read_table('.input/yelp_labelled.txt')
# df_imdb = pd.read_table('.input/imdb_labelled.txt')
# df_amz = pd.read_table('.input/amazon_cells_labelled.txt')

# Set path to the data files
path = './input/'

# Add column names
col_names = ['Text', 'Label']

# Import data files as Pandas Dataframes
df_yelp = pd.read_table(path+'yelp_labelled.txt', names=col_names)
df_amz = pd.read_table(path+'amazon_cells_labelled.txt', names=col_names) # Use as test dataset
df_imdb = pd.read_table(path+'imdb_labelled.txt', names=col_names)

# %%
# Concatenate our Datasets
frames = [df_yelp,df_imdb,df_amz]

# %%
# Renaming Column Headers
for colname in frames:
    colname.columns = ["Message","Target"]

# %%
# Column names
for colname in frames:
    print(colname.columns)
# Out:
# Index(['Message', 'Target'], dtype='object')
# Index(['Message', 'Target'], dtype='object')
# Index(['Message', 'Target'], dtype='object')

# %%
# Assign a Key to Make it Easier
keys = ['Yelp','IMDB','Amazon']

# %%
# Merge or Concat our Datasets
df = pd.concat(frames,keys=keys)

# %%
# Length and Shape 
df.shape
# Out:
# (2748, 2)

# %%
df.head()
# Out:
#                                                   Message  Target
# Yelp 0                           Wow... Loved this place.       1
#      1                                 Crust is not good.       0
#      2          Not tasty and the texture was just nasty.       0
#      3  Stopped by during the late May bank holiday of...       1
#      4  The selection on the menu was great and so wer...       1

# %%
# df.to_csv("sentimentdataset.csv")

# %%
# Data Cleaning
df.columns
# Out:
# Index(['Message', 'Target'], dtype='object')

# %%
# Checking for Missing Values
df.isnull().sum()
# Out:
# Message    0
# Target     0
# dtype: int64

# %% [markdown]
# ###  Working with SpaCy
# + Removing Stopwords
# + Lemmatizing

# %%
from  spacy.lang.en.stop_words import STOP_WORDS

# Build a list of stopwords to use to filter
stopwords = list(STOP_WORDS)

# %%
stopwords
# Out:
# ['every',
#  'per',
#  'part',
#  'none',
#  "n't",
#  'if',
#  'where',
#  'not',
#  'been',
#  'move',
#  'somehow',
#  'with',
#  'being',
#  'thereupon',
#  'whoever',
#  'what',
#  'only',
#  '‘m',
#  'somewhere',
#  'within',
#  'some',
#  'towards',
#  'keep',
#  'mostly',
#  '‘s',
#  'how',
#  'above',
#  'toward',
#  'up',
#  'though',
#  'afterwards',
#  'few',
#  'about',
#  'are',
#  'used',
#  'of',
#  'meanwhile',
#  'would',
#  'else',
#  'made',
#  'therein',
#  'twelve',
#  'back',
#  'two',
#  'most',
#  'these',
#  'without',
#  'everything',
#  'off',
#  'again',
#  'were',
#  'wherever',
#  'could',
#  'three',
#  'go',
#  'too',
#  'alone',
#  'often',
#  'nowhere',
#  'among',
#  'seems',
#  'must',
#  'formerly',
#  'although',
#  'six',
#  'get',
#  'serious',
#  'my',
#  '’re',
#  'much',
#  'them',
#  'our',
#  'eleven',
#  'thereafter',
#  'see',
#  'please',
#  'below',
#  '‘ve',
#  '‘d',
#  'we',
#  '’d',
#  'various',
#  'during',
#  '’ll',
#  'into',
#  'first',
#  'five',
#  'show',
#  'or',
#  'side',
#  'neither',
#  'using',
#  'whereas',
#  'next',
#  'either',
#  'between',
#  'whose',
#  'therefore',
#  'and',
#  'former',
#  'was',
#  'us',
#  'hereby',
#  '‘ll',
#  'yours',
#  'him',
#  'fifteen',
#  'sometimes',
#  'a',
#  'whom',
#  'whether',
#  'enough',
#  'further',
#  'take',
#  'nevertheless',
#  'along',
#  'one',
#  'hereafter',
#  'thence',
#  'done',
#  'via',
#  'beforehand',
#  'he',
#  'than',
#  'rather',
#  'everyone',
#  'can',
#  'her',
#  'regarding',
#  'but',
#  'down',
#  'seem',
#  'mine',
#  'to',
#  'becomes',
#  'bottom',
#  'due',
#  'any',
#  'behind',
#  'anywhere',
#  'ourselves',
#  'why',
#  'however',
#  'after',
#  'someone',
#  'really',
#  'became',
#  'nor',
#  'still',
#  'everywhere',
#  'other',
#  'had',
#  'across',
#  'anyway',
#  'become',
#  'unless',
#  'yourselves',
#  'itself',
#  'least',
#  'here',
#  'anyone',
#  'myself',
#  'throughout',
#  'an',
#  'is',
#  'quite',
#  'while',
#  'already',
#  'forty',
#  'am',
#  'herein',
#  'the',
#  'might',
#  'she',
#  'whereupon',
#  'does',
#  'me',
#  'i',
#  'which',
#  'even',
#  'ca',
#  'have',
#  'say',
#  'should',
#  'onto',
#  'make',
#  'through',
#  'give',
#  'did',
#  'except',
#  'whence',
#  "'s",
#  'noone',
#  'another',
#  'hers',
#  'since',
#  'eight',
#  'latter',
#  'each',
#  'their',
#  'whenever',
#  'wherein',
#  'against',
#  'all',
#  'on',
#  'amount',
#  'herself',
#  'both',
#  'less',
#  "'m",
#  'ever',
#  'themselves',
#  "'ve",
#  'ten',
#  'nobody',
#  'by',
#  'full',
#  'same',
#  'its',
#  'otherwise',
#  'anything',
#  'will',
#  'for',
#  'beyond',
#  'empty',
#  're',
#  'it',
#  'has',
#  'your',
#  'never',
#  'twenty',
#  'many',
#  'name',
#  'that',
#  'thereby',
#  'thru',
#  'also',
#  'himself',
#  'fifty',
#  '’ve',
#  'four',
#  'n‘t',
#  'you',
#  'so',
#  'call',
#  'well',
#  'moreover',
#  'they',
#  'doing',
#  'front',
#  'last',
#  'whole',
#  'thus',
#  'those',
#  'there',
#  'seeming',
#  'beside',
#  'under',
#  'own',
#  'third',
#  'whatever',
#  'upon',
#  'ours',
#  'whither',
#  'yet',
#  'be',
#  'over',
#  'latterly',
#  'amongst',
#  'namely',
#  'out',
#  'seemed',
#  'nine',
#  'his',
#  'top',
#  'nothing',
#  'around',
#  'whereafter',
#  'something',
#  'because',
#  "'re",
#  'when',
#  'at',
#  'then',
#  'such',
#  'hereupon',
#  'whereby',
#  '’s',
#  'put',
#  'before',
#  'from',
#  'several',
#  'until',
#  '‘re',
#  'do',
#  'cannot',
#  'very',
#  'becoming',
#  'hundred',
#  'indeed',
#  'who',
#  'just',
#  'more',
#  'besides',
#  'now',
#  'always',
#  'n’t',
#  'this',
#  'elsewhere',
#  'others',
#  'almost',
#  "'d",
#  'sometime',
#  '’m',
#  "'ll",
#  'may',
#  'hence',
#  'yourself',
#  'as',
#  'no',
#  'anyhow',
#  'once',
#  'perhaps',
#  'together',
#  'sixty',
#  'in']

# %% [markdown]
# ##### Getting Lemma and Stop words

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
docx = nlp("This is how John Walker was walking. He was also running beside the lawn.")
type(docx)
# Out:
# spacy.tokens.doc.Doc

# %%
# Lemmatizing of tokens
for word in docx:
    print(word.text,"Lemma =>",word.lemma_)
# Out:
# This Lemma => this
# is Lemma => be
# how Lemma => how
# John Lemma => John
# Walker Lemma => Walker
# was Lemma => be
# walking Lemma => walk
# . Lemma => .
# He Lemma => -PRON-
# was Lemma => be
# also Lemma => also
# running Lemma => run
# beside Lemma => beside
# the Lemma => the
# lawn Lemma => lawn
# . Lemma => .

# %%
# Lemma that are not pronouns
for word in docx:
    if word.lemma_ != "-PRON-":
        print(word.lemma_.lower().strip())
# Out:
# this
# be
# how
# john
# walker
# be
# walk
# .
# be
# also
# run
# beside
# the
# lawn
# .

# %%
# List Comprehensions of our Lemma
[word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in docx]
# Out:
# ['this',
#  'be',
#  'how',
#  'john',
#  'walker',
#  'be',
#  'walk',
#  '.',
#  'he',
#  'be',
#  'also',
#  'run',
#  'beside',
#  'the',
#  'lawn',
#  '.']

# %%
# Filtering out Stopwords and Punctuations
for word in docx:
    if word.is_stop == False and not word.is_punct:
#     if word.is_stop != True and not word.is_punct:
        print(word)
# Out:
# John
# Walker
# walking
# running
# lawn

# %%
# Stop words and Punctuation In List Comprehension
[ word for word in docx if word.is_stop == False and not word.is_punct ]
# Out:
# [John, Walker, walking, running, lawn]

# %%
# Use the punctuations of string module
import string
punctuations = string.punctuation

# %%
# Creating a Spacy Parser
from spacy.lang.en import English
parser = English()

# %%
def spacy_tokenizer(sentence):
    mytokens = parser(sentence)
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]
    mytokens = [ word for word in mytokens if word not in stopwords and word not in punctuations ]
    return mytokens

# %%
spacy_tokenizer("This is how John Walker was walking. He was also running beside the lawn.")
# Out:
# ['john', 'walker', 'walking', 'running', 'lawn']

# %%
type(spacy_tokenizer("This is how John Walker was walking. He was also running beside the lawn."))
# Out:
# list

# %% [markdown]
# #### Machine Learning With SKlearn

# %%
# ML Packages
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.metrics import accuracy_score 
from sklearn.base import TransformerMixin 
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC

# %%
#Custom transformer using spaCy 
class predictors(TransformerMixin):
    def transform(self, X, **transform_params):
        return [clean_text(text) for text in X]
    def fit(self, X, y=None, **fit_params):
        return self
    def get_params(self, deep=True):
        return {}

# Basic function to clean the text 
def clean_text(text):     
    return text.strip().lower()

# %%
# Vectorization
vectorizer = CountVectorizer(tokenizer = spacy_tokenizer, ngram_range=(1,1)) 
classifier = LinearSVC()

# %%
# Using Tfidf
tfvectorizer = TfidfVectorizer(tokenizer = spacy_tokenizer)

# %%
# Splitting Data Set
from sklearn.model_selection import train_test_split

# %%
# Features and Labels
X = df['Message']
ylabels = df['Target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, ylabels, test_size=0.2, random_state=42)

# %%
# Create the  pipeline to clean, tokenize, vectorize, and classify 
pipe = Pipeline([("cleaner", predictors()),
                 ('vectorizer', vectorizer),
                 ('classifier', classifier)])

# %%
# Fit our data
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('cleaner', <__main__.predictors object at 0x000001DDC83E7F40>),
#                 ('vectorizer',
#                  CountVectorizer(tokenizer=<function spacy_tokenizer at 0x000001DDC00D0E50>)),
#                 ('classifier', LinearSVC())])

# %%
# Predicting with a test dataset
sample_prediction = pipe.predict(X_test)

# %%
# Prediction Results
# 1 = Positive review
# 0 = Negative review
for (sample,pred) in zip(X_test,sample_prediction):
    print(sample,"Prediction=>",pred)
# Out:
# Great product. Prediction=> 1
# This product is very High quality Chinese CRAP!!!!!! Prediction=> 0
# Let's start with all the problemsthe acting, especially from the lead professor, was very, very bad.   Prediction=> 0
# It's too bad that everyone else involved didn't share Crowe's level of dedication to quality, for if they did, we'd have a far better film on our hands than this sub-par mess.   Prediction=> 0
# It always cuts out and makes a beep beep beep sound then says signal failed. Prediction=> 0
# Generous portions and great taste. Prediction=> 1
# Whatever prompted such a documentary is beyond me!   Prediction=> 0
# This phone might well be the worst I've ever had in any brand. Prediction=> 0
# Went for lunch - service was slow. Prediction=> 0
# Also, the fries are without a doubt the worst fries I've ever had. Prediction=> 0
# The refried beans that came with my meal were dried out and crusty and the food was bland. Prediction=> 0
# The only possible way this movie could be redeemed would be as MST3K fodder.   Prediction=> 0
# Bland and flavorless is a good way of describing the barely tepid meat. Prediction=> 0
# Service was exceptional and food was a good as all the reviews. Prediction=> 1
# Was not happy. Prediction=> 1
# You get what you pay for I guess. Prediction=> 0
# Be sure to order dessert, even if you need to pack it to-go - the tiramisu and cannoli are both to die for. Prediction=> 1
# I still maintain that monkeys shouldn't make headphones, we just obviously don't share enough DNA to copy the design over to humans. Prediction=> 0
# Everyone is very attentive, providing excellent customer service. Prediction=> 1
# To be honest with you, this is unbelievable nonsense and very foolish.   Prediction=> 0
# Not a good item.. It worked for a while then started having problems in my auto reverse tape player. Prediction=> 0
# I'm not really sure how Joey's was voted best hot dog in the Valley by readers of Phoenix Magazine. Prediction=> 1
# Very poor service. Prediction=> 0
# sucked, most of the stuff does not work with my phone. Prediction=> 0
# In short - this was a monumental waste of time and energy and I would not recommend anyone to EVER see this film.   Prediction=> 0
# You also cannot take pictures with it in the case because the lense is covered. Prediction=> 1
# If you're not familiar, check it out. Prediction=> 1
# Mic Doesn't work. Prediction=> 0
# The food came out at a good pace. Prediction=> 1
# Ordered a double cheeseburger & got a single patty that was falling apart (picture uploaded) Yeah, still sucks. Prediction=> 0
# Well packaged, arrived on time, and works as intended. Prediction=> 1
# I liked it.   Prediction=> 1
# I probably won't be coming back here. Prediction=> 0
# The ambiance here did not feel like a buffet setting, but more of a douchey indoor garden for tea and biscuits. Prediction=> 0
# It felt like a very gripping, intelligent stage play (but without the overly theatrical feeling one actually gets from watching people on a stage) which plays on everyone's terror of a white lie escalating to monstrous consequences.   Prediction=> 1
# Hayao Miyazaki's latest and eighth film for Studio Ghibili, "Gake No Ue No Ponyo" (Ponyo on the Cliff by the Sea) is a wonderfully fun and imaginative look at childhood.   Prediction=> 1
# Come hungry, leave happy and stuffed! Prediction=> 1
# Just does not work. Prediction=> 0
# I find wasting food to be despicable, but this just wasn't food. Prediction=> 0
# I could not recommend these more. Prediction=> 1
# This is an extraordinary film.   Prediction=> 0
# The fried rice was dry as well. Prediction=> 0
# The sets (especially designed to work with the camera) are amazing....stylized, beautiful and effective.   Prediction=> 1
# My brother in law who works at the mall ate here same day, and guess what he was sick all night too. Prediction=> 1
# So Far So Good!. Prediction=> 1
# End of Days is one of the worst big-budget action movies I've ever seen.   Prediction=> 0
# Pretty piece of junk. Prediction=> 0
# The food is about on par with Denny's, which is to say, not good at all. Prediction=> 0
# I found this place by accident and I could not be happier. Prediction=> 1
# The update procedure is difficult and cumbersome. Prediction=> 0
# Waste of money. Prediction=> 0
# I vomited in the bathroom mid lunch. Prediction=> 0
# Nine out of ten for a truly lovely film.   Prediction=> 1
# It would take too long to describe how bad my customer service experience has been with Amazon. Prediction=> 0
# The movie has almost no action scenes in it and very little comedy.   Prediction=> 1
# Weird vibe from owners. Prediction=> 1
# This was my first time and I can't wait until the next. Prediction=> 1
# And the drinks are WEAK, people! Prediction=> 0
# The "explosion" of the Gas tanks at the end was just as awful.   Prediction=> 0
# $50 Down the drain. Prediction=> 0
# Reaching for the bottom row is uncomfortable, and the send and end keys are not where I expect them to be.3. Prediction=> 0
# With the originality and freshness of the first movie now spent, this remake had little else to offer.   Prediction=> 0
# For about 10 minutes, we we're waiting for her salad when we realized that it wasn't coming any time soon. Prediction=> 0
# It was way over fried. Prediction=> 0
# I don't think we'll be going back anytime soon. Prediction=> 0
# And generally the lines and plot is weaker than the average episode.   Prediction=> 0
# Again, no plot at all.   Prediction=> 0
# Not a good bargain. Prediction=> 1
# Before I go in to why I gave a 1 star rating please know that this was my third time eating at Bachi burger before writing a review. Prediction=> 0
# The script iswas there a script?   Prediction=> 0
# The case is great and works fine with the 680. Prediction=> 1
# In fact I'm going to round up to 4 stars, just because she was so awesome. Prediction=> 1
# It is cheap, and it feel and look just as cheap. Prediction=> 0
# Director Neil LaBute uses brutal violence to seperate dreams from reality, and along with the touching drama, and hilarious comedy, you can never tell what is going to happen next.   Prediction=> 0
# As many people complained, I found this headset's microphone was very weak. Prediction=> 1
# No ear loop needed, it's tiny and the sound is great. Prediction=> 1
# You can not answer calls with the unit, never worked once! Prediction=> 0
# Yes, I am simplifying things here for the sake of brevity, for this really is at the core of the problems with this film - it has too much going on without any real, fulfilling explanation.   Prediction=> 0
# Overall, I would recommend this phone over the new Walkman. Prediction=> 1
# Perhaps I caught them on an off night judging by the other reviews, but I'm not inspired to go back. Prediction=> 1
# Perfect for someone (me) who only likes beer ice cold, or in this case, even colder. Prediction=> 1
# Not a single employee came out to see if we were OK or even needed a water refill once they finally served us our food. Prediction=> 0
# For the price on Amazon, it is an excellent product, which I would highly recommend. Prediction=> 1
# Piece of Junk. Prediction=> 0
# I saw it as a child on TV back in 1973, when it was "The Stranger" and I loved it.   Prediction=> 1
# Also, it's a real treat to see Anthony Quinn playing Crazy Horse.   Prediction=> 1
# Mediocre food. Prediction=> 0
# Im big fan of RPG games too, but this movie, its a disgrace to any self-respecting RPGer there is.   Prediction=> 0
# The best place in Vegas for breakfast (just check out a Sat, or Sun. Prediction=> 1
# I really loved the story line and the poler bear was kinda cute.But if anyone has a question about Fort Steele, just ask away:)   Prediction=> 1
# Waited and waited and waited. Prediction=> 0
# I liked the way Dustin Hoffman's character was ready to do just about everything to stay with his son.   Prediction=> 1
# Despite how hard I rate businesses, its actually rare for me to give a 1 star. Prediction=> 0
# Every time he opened his mouth you expect to hear, "you see kids..." Pulling the plug was a mercy killing for this horrible show.   Prediction=> 0
# It took over 30 min to get their milkshake, which was nothing more than chocolate milk. Prediction=> 0
# This is the phone to get for 2005.... I just bought my S710a and all I can say is WOW! Prediction=> 0
# Their rotating beers on tap is also a highlight of this place. Prediction=> 0
# It quit working after I'd used it for about 18 months, so I just purchased another one because this is the best headset I've ever owned. Prediction=> 1
# Despite the pans of reviewers, I liked this movie.   Prediction=> 1
# The best example of how dumb the writing is when it's established that you can turn the zombie-students back into humans by removing a necklace containing a piece of the meteorite.   Prediction=> 0
# The rest of the movie lacks art, charm, meaning... If it's about emptiness, it works I guess because it's empty.   Prediction=> 1
# Yes it's shiny on front side - and I love it! Prediction=> 1
# Appears to actually outperform the original battery from China that came with my V325i. Prediction=> 1
# too bad cause I know it's family owned, I really wanted to like this place. Prediction=> 1
# Hot dishes are not hot, cold dishes are close to room temp.I watched staff prepare food with BARE HANDS, no gloves.Everything is deep fried in oil. Prediction=> 0
# Emily Watson's character is very strong, and she has only to give a quick glance and you understand everything.   Prediction=> 1
# The headsets are easy to use and everyone loves them. Prediction=> 1
# Favorite place in town for shawarrrrrrma!!!!!! Prediction=> 1
# This place should honestly be blown up. Prediction=> 0
# Coming here is like experiencing an underwhelming relationship where both parties can't wait for the other person to ask to break up. Prediction=> 1
# I LOVED it! Prediction=> 1
# I waited and waited. Prediction=> 0
# The waiter wasn't helpful or friendly and rarely checked on us. Prediction=> 1
# Please dont waste your money. Prediction=> 0
# Unfortunately, inexperience of direction meant that scene after scene passed with little in the way of dramatic tension or conflict.   Prediction=> 0
# I'll put this gem up against any movie in terms of screenplay, cinematography, acting, post-production, editing, directing, or any other aspect of film-making.   Prediction=> 0
# Don't bother - go to the store. Prediction=> 0
# Thoroughly disappointed! Prediction=> 0
# The characters are fleshed out surprisingly well, particularly Grimes and Blake, and all the actors deliver their sharply scripted lines with just the right amount of deadpan tongue in cheek to make the dialogue both hilarious and realistic.   Prediction=> 0
# The best electronics of the available FM Transmitters. Prediction=> 1
# While you don't yet hear Mickey speak, there are tons of sound effects and music throughout the film--something we take for granted now but which was a huge crowd pleaser in 1928.   Prediction=> 0
# Basically the service was very bad. Prediction=> 0
# The manager was the worst. Prediction=> 0
# I'm terribly disappointed that this film would receive so many awards and accolades, especially when there are far more deserving works of film out there.   Prediction=> 1
# I love this phone!. Prediction=> 1
# The directing seems too pretentious.   Prediction=> 0
# The opening sequence of this gem is a classic, and the cat n mouse games that follow are a delight to watch.   Prediction=> 0
# I am more than happy with this product. Prediction=> 1
# The movie was very interesting from beginning to the end.   Prediction=> 1
# Gets the job done. Prediction=> 0
# The calls drop, the phone comes on and off at will, the screen goes black and the worst of all it stops ringing intermittently. Prediction=> 0
# If you like a loud buzzing to override all your conversations, then this phone is for you! Prediction=> 0
# Final Word: This Show is a real torture!!   Prediction=> 0
# Frozen pucks of disgust, with some of the worst people behind the register. Prediction=> 0
# As for the service, I thought it was good. Prediction=> 1
# The nokia CA-42 USB cable did not work with my phone. Prediction=> 0
# But "Tiny Toons" kept the 90's vibe and delivered one of the most popular, funny, and underrated cartoons ever created.   Prediction=> 1
# This isn't a small family restaurant, this is a fine dining establishment. Prediction=> 1
# I rather enjoyed it.   Prediction=> 1
# Food was delicious! Prediction=> 1
# Also makes it easier to hold on to. Prediction=> 0
# Best breakfast buffet!!! Prediction=> 1
# It is light, has plenty of battery capacity, and is very confortable to wear for somewhat extended periods of time. Prediction=> 1
# You won't regret it! Prediction=> 1
# My gyro was basically lettuce only. Prediction=> 0
# The live music on Fridays totally blows. Prediction=> 0
# The place was not clean and the food oh so stale! Prediction=> 0
# The battery works great! Prediction=> 1
# Customer service was terrible. Prediction=> 0
# Worst Customer Service Ever. Prediction=> 0
# John Garfield, Ann revere, Lilli Plmer, William Conrad, Canada Lee...and filmed by one of the greatest cinematographers to ever grace the screen..James Wong Howe.   Prediction=> 1
# This is a stunning movie.   Prediction=> 0
# The best scene in the movie was when Gerardo is trying to find a song that keeps running through his head.   Prediction=> 1
# The things that the four kids get themselves into is absolutely hilarious to watch.   Prediction=> 0
# Dont waste your money... Prediction=> 0
# The Jabra EarGels fit my ears very well. Prediction=> 0
# This is one of the worst Sandra Bullock movie since Speed 2 But not quite that bad.   Prediction=> 0
# Would come back again if I had a sushi craving while in Vegas. Prediction=> 1
# If you like a loud buzzing to override all your conversations, then this phone is for you! Prediction=> 0
# Talk about USELESS customer service. Prediction=> 0
# We had a group of 70+ when we claimed we would only have 40 and they handled us beautifully. Prediction=> 0
# There is no plot here to keep you going in the first place.   Prediction=> 0
# 10/10   Prediction=> 0
# Horrible, horrible protector. Prediction=> 0
# The deal included 5 tastings and 2 drinks, and Jeff went above and beyond what we expected. Prediction=> 0
# Then, as if I hadn't wasted enough of my life there, they poured salt in the wound by drawing out the time it took to bring the check. Prediction=> 1
# MANNA FROM HEAVEN is a terrific film that is both predictable and unpredictable at the same time.   Prediction=> 1
# Not a weekly haunt, but definitely a place to come back to every once in a while. Prediction=> 1
# The Heart Attack Grill in downtown Vegas is an absolutely flat-lined excuse for a restaurant. Prediction=> 1
# The results, well, are a shame.   Prediction=> 0
# And considering the two of us left there very full and happy for about $20, you just can't go wrong. Prediction=> 0
# A very, very, very slow-moving, aimless movie about a distressed, drifting young man.   Prediction=> 0
# VERY DISAPPOINTED. Prediction=> 0
# The cutouts and buttons are placed perfectly. Prediction=> 1
# Would not reccommend. Prediction=> 0
# Very Dissapointing Performance. Prediction=> 1
# Judith Light is one of my favorite actresses and I think she does a superb job in this film!   Prediction=> 1
# I will never go back to this place and will never ever recommended this place to anyone! Prediction=> 1
# Could not get strong enough signal. Prediction=> 0
# AN HOUR... seriously? Prediction=> 0
# We thought you'd have to venture further away to get good sushi, but this place really hit the spot that night. Prediction=> 1
# The charger arrived within the promised timeframe, but it did not work. Prediction=> 0
# The text messaging feature is really tricky to use. Prediction=> 1
# The fat computer geek was unbelievable, the bible thumper, the bad-ass girl, who are these actors???   Prediction=> 0
# The food was very good and I enjoyed every mouthful, an enjoyable relaxed venue for couples small family groups etc. Prediction=> 1
# Five star Plus, plus. Prediction=> 1
# I also didn't like the "on" button, it felt like it would crack with use. Prediction=> 0
# Well... Just if you keep thinking how bad it is.   Prediction=> 0
# Overall I wasn't very impressed with Noca. Prediction=> 0
# The cast of veteran actors are more than just a nostalgia trip.   Prediction=> 1
# It's a great place and I highly recommend it. Prediction=> 1
# She carries the movie well.   Prediction=> 0
# Some applause should be given to the "prelude" however.   Prediction=> 0
# I won't try going back there even if it's empty. Prediction=> 0
# I am so tired of clichés that is just lazy writing, and here they come in thick and fast.   Prediction=> 1
# And, FINALLY, after all that, we get to an ending that would've been great had it been handled by competent people and not Jerry Falwell.   Prediction=> 1
# I received it quickly and it works great!! Prediction=> 1
# The phone loads super! Prediction=> 0
# No, I'm going to eat the potato that I found some strangers hair in it. Prediction=> 0
# I had the chicken Pho and it tasted very bland. Prediction=> 0
# The screen does get smudged easily because it touches your ear and face. Prediction=> 0
# All the pretty pictures in the world cannot make up for a piece of work that is flawed at the core.   Prediction=> 0
# I have tried these cables with my computer and my iPod and it works just fine. Prediction=> 1
# Not only will it drain your player, but may also potentially fry it. Prediction=> 0
# Don't waste your money!. Prediction=> 0
# From what my dinner companions told me...everything was very fresh with nice texture and taste. Prediction=> 1
# The only thing I did like was the prime rib and dessert section. Prediction=> 0
# The owners are super friendly and the staff is courteous. Prediction=> 1
# Logitech Bluetooth Headset is a 10!. Prediction=> 1
# This is a good battery, and it got here really fast. Prediction=> 1
# The least said about the acting the better.   Prediction=> 1
# They refuse to refund or replace. Prediction=> 1
# We'd definitely go back here again. Prediction=> 1
# An excellent performance from Ms.   Prediction=> 1
# This item worked great, but it broke after 6 months of use. Prediction=> 1
# I do love sushi, but I found Kabuki to be over-priced, over-hip and under-services. Prediction=> 1
# Never again will I be dining at this place! Prediction=> 1
# Don't buy this product. Prediction=> 0
# Service was fantastic. Prediction=> 1
# I agree with Jessica, this movie is pretty bad.   Prediction=> 0
# It was so BORING!   Prediction=> 0
# The chips that came out were dripping with grease, and mostly not edible. Prediction=> 0
# She was quite disappointed although some blame needs to be placed at her door. Prediction=> 0
# Having to humour him just to get by and get through the day was so apt.   Prediction=> 0
# The range is very decent, I've been able to roam around my house with the phone in the living room with no reception/sound quality issues. Prediction=> 1
# WELL IM SATISFIED. Prediction=> 1
# I've tried several different earpieces for my cell phone and this Jabra one is the first one I've found that fits my ear comfortably. Prediction=> 1
# And then tragedy struck. Prediction=> 0
# Not recommended.   Prediction=> 1
# No shifting, no bubbling, no peeling, not even a scratch, NOTHING!I couldn't be more happier with my new one for the Droid. Prediction=> 1
# Great Product. Prediction=> 1
# The worst was the salmon sashimi. Prediction=> 0
# Linked to my phone without effort. Prediction=> 0
# Lange had become a great actress.   Prediction=> 1
# Works great. Prediction=> 1
# nice leather. Prediction=> 1
# fast service. Prediction=> 1
# You need two hands to operate the screen.This software interface is decade old and cannot compete with new software designs. Prediction=> 1
# Food is way overpriced and portions are fucking small. Prediction=> 0
# It has northern humour and positive about the community it represents.   Prediction=> 0
# What I really like there is the crepe station. Prediction=> 1
# Never heard of any of them except Cole who was totally unbelievable in the part.   Prediction=> 0
# We also ordered the spinach and avocado salad; the ingredients were sad and the dressing literally had zero taste. Prediction=> 0
# horrible, had to switch 3 times. Prediction=> 0
# Rip off---- Over charge shipping. Prediction=> 1
# On a positive note, our server was very attentive and provided great service. Prediction=> 1
# All I have to say is the food was amazing!!! Prediction=> 1
# Definitely not worth the $3 I paid. Prediction=> 0
# But when I check voice mail at night, the keypad backlight turns off a few seconds into the first message, and then I'm lost. Prediction=> 1
# But this movie is definitely a below average rent.   Prediction=> 1
# I don't have very many words to say about this place, but it does everything pretty well. Prediction=> 1
# Both do good jobs and are quite amusing.   Prediction=> 1
# Still, it makes up for all of this with a super ending that depicts a great sea vessel being taken out by the mighty frost.   Prediction=> 1
# I think this restaurant suffers from not trying hard enough. Prediction=> 0
# One of the most boring,pointless movies I have ever seen.   Prediction=> 0
# Great choice! Prediction=> 1
# I am sorry I made this purchase. Prediction=> 0
# A FLY was in my apple juice.. A FLY!!!!!!!! Prediction=> 1
# The acting was bad, the dialogs were extremely shallow and insincere.   Prediction=> 0
# Bad Purchase. Prediction=> 0
# We watched our waiter pay a lot more attention to other tables and ignore us. Prediction=> 0
# I have watched their prices inflate, portions get smaller and management attitudes grow rapidly! Prediction=> 0
# And the accents are absolutely abysmal!   Prediction=> 1
# It was delicious!!! Prediction=> 1
# An interesting premise, and Billy Drago is always good as a dangerous nut-bag (side note: I'd love to see Drago, Stephen McHattie and Lance Hendrikson in a flick together; talk about raging cheekbones!).   Prediction=> 1
# This phone is slim and light and the display is beautiful. Prediction=> 1
# After a year the battery went completely dead on my headset. Prediction=> 0
# Delicious NYC bagels, good selections of cream cheese, real Lox with capers even. Prediction=> 1
# The feel of the dining room was more college cooking course than high class dining and the service was slow at best. Prediction=> 1
# This place deserves no stars. Prediction=> 1
# I bought this battery with a coupon from Amazon and I'm very happy with my purchase. Prediction=> 0
# Over rated. Prediction=> 0
# The warmth it generates is in contrast to its austere backdrop.   Prediction=> 0
# 20th Century Fox's ROAD HOUSE 1948) is not only quite a silly noir but is an implausible unmitigated bore of a movie.   Prediction=> 0
# Totally different, with loads of understatement and black comedy, this is a film few get to see, but those who do will remember it.   Prediction=> 0
# It is a true classic.   Prediction=> 1
# Plus, it was well-paced and suited its relatively short run time.   Prediction=> 1
# The service was a bit lacking. Prediction=> 0
# The film deserves strong kudos for taking this stand, for having exceptional acting from its mostly lesser-known cast and for the super-intelligent script that doesn't insult the audience or take the easy way out when it comes to white racism.   Prediction=> 1
# Definitely worth checking out.   Prediction=> 1
# He is almost unbearable to watch on screen, he has little to no charisma, and terrible comedic timing.   Prediction=> 0
# Lordy, the Khao Soi is a dish that is not to be missed for curry lovers! Prediction=> 0
# Just whatever you do, avoid "Groove" as its the antithesis of all that is good about Human Traffic.   Prediction=> 0
# Arrived quickly and much less expensive than others being sold. Prediction=> 1
# Very nice and relaxing late night viewing.   Prediction=> 1
# Great product and price. Prediction=> 1
# I never come again. Prediction=> 1
# We waited for forty five minutes in vain. Prediction=> 0
# This place deserves one star and 90% has to do with the food. Prediction=> 1
# I use this product in a motor control center where there is a lot of high voltage humming from the equipment, and it works great! Prediction=> 1
# The Veggitarian platter is out of this world! Prediction=> 1
# .... Item arrived quickly and works great with my Metro PCS Samsung SCH-r450 slider phone and Sony Premium Sound in ear plugs. Prediction=> 1
# Then I watched it again two Sundays ago (March 20th, 2005) and I began to really enjoy it and this time I taped the entire thing.   Prediction=> 1
# It really created a unique feeling though.   Prediction=> 0
# Krussel Always good. Prediction=> 1
# Nice case, feels good in your hands. Prediction=> 1
# We walked away stuffed and happy about our first Vegas buffet experience. Prediction=> 0
# I'm so happy to be here!!!" Prediction=> 1
# I posted more detailed comments under the grey or black phone, but i have the Fire Red and it's a great color! Prediction=> 1
# I as well would've given godfathers zero stars if possible. Prediction=> 0
# After 3 months, screen just went black all of a sudden. Prediction=> 1
# What is even more stupid is that who had thought an idea that there should be a volcano in Los Angeles?   Prediction=> 0
# I don't think I've ever gone to a movie and disliked it as much.   Prediction=> 0
# The inside is really quite nice and very clean. Prediction=> 1
# Now the pizza itself was good the peanut sauce was very tasty. Prediction=> 1
# When I placed my treo into the case, not only was it NOT snug, but there was A LOT of extra room on the sides. Prediction=> 1
# Doesn't work at all.. I bougth it for my L7c and its not working. Prediction=> 1
# I love this device. Prediction=> 1
# I've never been treated so bad. Prediction=> 0
# Battery is holding up well. Prediction=> 0
# The construction of the headsets is poor. Prediction=> 0
# Just don't know why they were so slow. Prediction=> 0
# The movie is not completely perfect but 'Titta Di Girolamo' will stay with you for a long time after the vision of the movie.   Prediction=> 1
# I don't have to be an accountant to know I'm getting screwed! Prediction=> 1
# Great Subway, in fact it's so good when you come here every other Subway will not meet your expectations. Prediction=> 1
# I recently tried Caballero's and I have been back every week since! Prediction=> 0
# I want my money back. Prediction=> 0
# But in terms of the writing it's very fresh and bold.   Prediction=> 0
# Not frightening in the least, and barely comprehensible.   Prediction=> 0
# Waste of 13 bucks. Prediction=> 0
# An extensive menu provides lots of options for breakfast. Prediction=> 1
# It's been my choice headset for years.Great sound; good volume; good noise cancellation. Prediction=> 1
# His acting alongside Olivia De Havilland was brilliant and the ending was fantastic!   Prediction=> 1
# Warning - Stay away. Prediction=> 0
# This film offers many delights and surprises.   Prediction=> 0
# I recently had problems where I could not stay connected for more than 10 minutes before being disconnected. Prediction=> 0
# If that bug never showed up I would have given a 4 for sure, but on the other side of the wall where this bug was climbing was the kitchen. Prediction=> 0
# During several different 2 minute calls, I experienced 5 drops and it was in an area that had 5 bars. Prediction=> 0
# I bought this to use with my Kindle Fire and absolutely loved it! Prediction=> 1
# definitely will come back here again. Prediction=> 1
# Also notable is John Bailey's fine crisp beautifully colored cinematography and the great production design & costumes by Eiko Ishioka who went on to do the memorable costumes for Coppola's Dracula for which she received a well deserved Oscar.   Prediction=> 1
# Voice Quality, Signal Strength, Dropped Calls. Prediction=> 0
# This was one of the worst films i have ever seen.   Prediction=> 0
# Gave up trying to eat any of the crust (teeth still sore). Prediction=> 0
# The staff are great, the ambiance is great. Prediction=> 1
# But despite these few flaws, this case is of exceptional quality and well worth the additional costs of owning an official OEM product. Prediction=> 0
# One of my favorite purchases ever. Prediction=> 0
# Headset works great & was packaged nicely to avoid any damage. Prediction=> 1
# Highly recommend for any one who has a blue tooth phone. Prediction=> 1
# These are fabulous! Prediction=> 1
# We had fantastic service, and were pleased by the atmosphere. Prediction=> 1
# Lifetime does not air it enough, so if anyone knows what store sells it let me know because this is a must-have.   Prediction=> 0
# Nice design and quality. Prediction=> 1
# 10/10   Prediction=> 0
# If this premise sound stupid, that's because it is.   Prediction=> 0
# The chips and sals a here is amazing!!!!!!!!!!!!!!!!!!! Prediction=> 1
# The service was poor and thats being nice. Prediction=> 0
# If you do go see this movie, bring a pillow or a girlfriend/boyfriend to keep you occupied through out.   Prediction=> 1
# Food was really good and I got full petty fast. Prediction=> 1
# It is worth the drive. Prediction=> 0
# Disappointed!. Prediction=> 0
# However, this didn't make up for the fact that overall, this was a tremendously boring movie.   Prediction=> 0
# I hate to disagree with my fellow Yelpers, but my husband and I were so disappointed with this place. Prediction=> 0
# Seriously flavorful delights, folks. Prediction=> 0
# Very Displeased. Prediction=> 0
# At a time when it seems that film animation has been dominated by Disney/Pixar's CGI masterpieces, it is both refreshing and comforting to know that Miyazaki is still relying on traditional hand-drawn animation to tell his charming and enchanting stories.   Prediction=> 0
# Also the area where my unit broke).- I'm not too fond of the magnetic strap. Prediction=> 0
# Terrible phone holder. Prediction=> 0
# I don't know what kind it is but they have the best iced tea. Prediction=> 1
# The visual effects were AWFUL.   Prediction=> 0
# Overall, a delight!   Prediction=> 1
# Not a pleasant voyage of self-discovery.   Prediction=> 0
# Enough can not be said of the remarkable animation in this film.   Prediction=> 0
# The worst phone I've ever had.... Only had it for a few months. Prediction=> 0
# The one down note is the ventilation could use some upgrading. Prediction=> 0
# Im in AZ all the time and now have my new spot. Prediction=> 1
# This scene is very strong and unpleasant.   Prediction=> 1
# All the other cases I've tried normally fall apart after a few months but this one seems to be in for the long haul. Prediction=> 1
# When Achille and Philippa beautifully sing a duet from "Don Giovanni" that perfectly describes their situation in the movie, you appreciate the subtle layers of this excellent film.   Prediction=> 1
# Elias Koteas,Jack Palance play good roles Angelina is hot and gets naked.Billy Drago appears in this and is cool as usual + a cameo by Sven ole Thorsen helps make this a very enjoyable movie with good acting and a decent budget.   Prediction=> 1
# This is one of the better buffets that I have been to. Prediction=> 1
# I Was Hoping for More. Prediction=> 0
# Vivian Schilling did an excellent job with the script.   Prediction=> 1
# Better Than New. Prediction=> 0
# If you love authentic Mexican food and want a whole bunch of interesting, yet delicious meats to choose from, you need to try this place. Prediction=> 1
# Ordered an appetizer and took 40 minutes and then the pizza another 10 minutes. Prediction=> 0
# Does not fit. Prediction=> 0
# This is an unbelievable BARGAIN! Prediction=> 0
# If the food isn't bad enough for you, then enjoy dealing with the world's worst/annoying drunk people. Prediction=> 0
# It was very popular when I was in the cinema, a good house and very good reactions and plenty of laughs.   Prediction=> 1
# Service was slow and not attentive. Prediction=> 0
# At least 40min passed in between us ordering and the food arriving, and it wasn't that busy. Prediction=> 1
# He came running after us when he realized my husband had left his sunglasses on the table. Prediction=> 0
# I can't see how this movie can be an inspiration to anyone to come out or overcome fear and rejection.   Prediction=> 0
# Total brunch fail. Prediction=> 1
# Victor McLaglen was even bad, and Brian DonLevy was almost unrecognizable.   Prediction=> 0
# Simple, lightweight and great fit. Prediction=> 1
# Nargile - I think you are great. Prediction=> 1
# Furthermore, you can't even find hours of operation on the website! Prediction=> 0
# Service is quick and friendly. Prediction=> 1
# I have seen many movies starring Jaclyn Smith, but my god this was one of her best, though it came out 12 years ago.   Prediction=> 0
# After charging overnight, these batteries work great. Prediction=> 1
# Aside from it's terrible lead, this film has loads of other debits.   Prediction=> 0
# However, my recent experience at this particular location was not so good. Prediction=> 1
# Echo Problem....Very unsatisfactory Prediction=> 0
# I paid too much.   Prediction=> 0
# The design might be ergonomic in theory but I could not stand having these in my ear. Prediction=> 0
# The result is a film that just don't look right.   Prediction=> 1
# Constantine gives everything the right intensity and seems to have a good understanding of the underlying psychological motivations.   Prediction=> 1
# My friend loved the salmon tartar. Prediction=> 1
# The BT headset was such a disapoinment. Prediction=> 0
# Del Taco is pretty nasty and should be avoided if possible. Prediction=> 0
# I enjoyed it.   Prediction=> 1
# I kept catching the cable on the seat and I had to pull the phone out to turn it on an off. Prediction=> 1
# Never going back. Prediction=> 0
# I give Wirefly 1 star.I will contact Cingular/AT&T; and inform them of this practice. Prediction=> 0
# Join the club and get awesome offers via email. Prediction=> 1
# The whole experience was underwhelming, and I think we'll just go to Ninja Sushi next time. Prediction=> 0
# Its not user friendly. Prediction=> 1
# If someone orders two tacos don't' you think it may be part of customer service to ask if it is combo or ala cart? Prediction=> 1
# Their monster chicken fried steak and eggs is my all time favorite. Prediction=> 0
# Which are small and not worth the price. Prediction=> 1
# Unless you're just out to visually "collect" all extant films of Austen's work, you can skip this one.   Prediction=> 0
# I had to walk out of the theatre for a few minutes just to get some relief!   Prediction=> 0
# It is practically useless and did not add any kind of boost to my reception after I bought it. Prediction=> 0
# This was such an awesome movie that i bought it off of Ebay.   Prediction=> 1
# The headset fulfills my requirements so I am happy with my purchase. Prediction=> 1
# There is really nothing for me at postinos, hope your experience is better Prediction=> 1
# Disappointing experience. Prediction=> 0
# They had a toro tartare with a cavier that was extraordinary and I liked the thinly sliced wagyu with white truffle. Prediction=> 1
# Can't upload ringtones from a third party. Prediction=> 1
# Good show, Samsung. Prediction=> 1
# It's so stupid to have to keep buying new chargers, car chargers, cradles, headphones and car kits every time a new phone comes out. Prediction=> 0
# The plot, such as it is, is so derivative and predictable that the ending is like a mercy killing.   Prediction=> 1
# Not good enough for the price. Prediction=> 1
# I gave it a 10   Prediction=> 1
# The cable looks so thin and flimsy, it is scary. Prediction=> 1
# dont go here. Prediction=> 0
# It also took her forever to bring us the check when we asked for it. Prediction=> 0
# I would have casted her in that role after ready the script.   Prediction=> 0
# Works like a charm; it work the same as the one I got with the phone. Prediction=> 1
# Avoid this one if you can. Prediction=> 0
# See it with your kids if you have a chance--it will open up some amazing dialog about how far race relations have come in the last 50 years.   Prediction=> 1
# Technically, the film is well made with impressive camera-work, solid acting and effective music from Riz Ortolani  particularly good is a recurring unaccompanied female vocal that sounds like it's coming from a distant hill.   Prediction=> 1
# BT50 battery junk!. Prediction=> 0
# Works for me. Prediction=> 1
# Best fish I've ever had in my life! Prediction=> 1
# The incredible soundtrack truly captures the essence of the film.   Prediction=> 1
# You can't beat that. Prediction=> 1
# Oh yeah, and the storyline was pathetic too.   Prediction=> 0
# Best Buffet in town, for the price you cannot beat it. Prediction=> 1
# This movie is so awesome!   Prediction=> 1
# very tough and very short on flavor! Prediction=> 1
# Will be back again! Prediction=> 0
# There is nothing privileged about working/eating there. Prediction=> 1
# No allergy warnings on the menu, and the waitress had absolutely no clue as to which meals did or did not contain peanuts. Prediction=> 1
# I might have gotten a defect, but I would not risk buying it again because of the built quality alone. Prediction=> 0
# disappointing. Prediction=> 0
# Good case, Excellent value. Prediction=> 1
# Not good when wearing a hat or sunglasses. Prediction=> 0
# The staff is super nice and very quick even with the crazy crowds of the downtown juries, lawyers, and court staff. Prediction=> 1
# But the premise of the film was so ridiculous: that the President of the U.S.   Prediction=> 0
# Would not recommend to others. Prediction=> 1
# Bought mainly for the charger, which broke soon after purchasing. Prediction=> 1
# The bottowm line...another worthless, cheap gimmick from Sprint. Prediction=> 0
# Protects the phone on all sides. Prediction=> 0
# I wouldn't recommend buying this product. Prediction=> 0
# I can take a little bad service but the food sucks. Prediction=> 0
# After trying many many handsfree gadgets this is the one that finally works well. Prediction=> 1
# REALLY UGLY. Prediction=> 0
# Do not make the same mistake as me. Prediction=> 0
# Shrimp- When I unwrapped it (I live only 1/2 a mile from Brushfire) it was literally ice cold. Prediction=> 0
# Just reading on the specs alone makes you say WOW. Prediction=> 0
# WORST PHONE EVER. Prediction=> 0
# Anyway, I do not think i will go back there. Prediction=> 0
# I don't know what the big deal is about this place, but I won't be back "ya'all". Prediction=> 0
# This movie contained an all-star cast, and what I loved the most was that it opened my eyes to see other actors who I haven't seen before.   Prediction=> 0
# don't waste your money and time. Prediction=> 0
# The reception has been generally good. Prediction=> 1
# I highly recommend this movie for anyone interested in art, poetry, theater, politics, or Japanese history.   Prediction=> 1
# Doesn't do the job. Prediction=> 1
# Very Very Disappointed ordered the $35 Big Bay Plater. Prediction=> 0
# If you haven't gone here GO NOW! Prediction=> 0
# What a waste. Prediction=> 0
# Of course, the acting is blah.   Prediction=> 1
# This film has no redeeming features.   Prediction=> 1
# They also have the best cheese crisp in town. Prediction=> 1
# I've also had problems with the phone reading the memory card in which I always turn it on and then off again. Prediction=> 0
# Worst customer service. Prediction=> 0
# Att is not clear, sound is very distorted and you have to yell when you talk. Prediction=> 1
# I own 2 of these cases and would order another. Prediction=> 1
# The real killer is the volume, and of course it breaking. Prediction=> 0
# For sushi on the Strip, this is the place to go. Prediction=> 0
# The show would begin with smart ass ed comments to each other that would be totally off the wall and uncalled for.   Prediction=> 0
# Also there are combos like a burger, fries, and beer for 23 which is a decent deal. Prediction=> 0
# I've bought $5 wired headphones that sound better than these. Prediction=> 0
# I guess that nobody at the network that aired this dribble watched it before putting it on.   Prediction=> 0
# The movie in movie situations in the beginning and through the game that is played with her by the "acting coach" are fascinating.   Prediction=> 1
# All three broke within two months of use. Prediction=> 1
# Price is good too. Prediction=> 1
# An excellent new restaurant by an experienced Frenchman. Prediction=> 1
# Nothing special. Prediction=> 1
# Great charger. Prediction=> 1
# Update.....went back for a second time and it was still just as amazing Prediction=> 1
# So I bought about 10 of these and saved alot of money. Prediction=> 0
# I have been very satisfied with this cell phone from day one. Prediction=> 1
# Very, very sad. Prediction=> 0
# The screen size is big, key pad lit well enough, and the camera quality is excellent for a camera phone. Prediction=> 1
# I would have given no star if I was able. Prediction=> 1
# Not nearly as good looking as the AMAZON picture makes it look. Prediction=> 0
# Great price, too! Prediction=> 1
# I'll be drivng along, and my headset starts ringing for no reason. Prediction=> 0
# Funny, clever, hip - just like Pray's previous film, Hype!   Prediction=> 1
# VERY comfortable. Prediction=> 1
# It is easy to turn on and off when you are in the car and the volume controls are quite accessable. Prediction=> 0
# I kept looking at the time and it had soon become 35 minutes, yet still no food. Prediction=> 0
# So far it has worked like a charm. Prediction=> 1
# Everything is appalling.   Prediction=> 0
# It was a huge awkward 1.5lb piece of cow that was 3/4ths gristle and fat. Prediction=> 0
# This is a simple little phone to use, but the breakage is unacceptible. Prediction=> 1
# I'd say that would be the hardest decision... Honestly, all of M's dishes taste how they are supposed to taste (amazing). Prediction=> 1
# I did not expect this to be so good! Prediction=> 1
# very good product, well made. Prediction=> 1
# Sooooo good!! Prediction=> 1
# If you have several dozen or several hundred contacts, then imagine the fun of sending each of them one by one. Prediction=> 1
# Avoid at all cost! Prediction=> 0
# The phone can also take great pictures and even video clips. Prediction=> 1
# The Greek dressing was very creamy and flavorful. Prediction=> 1
# The volume switch rocketed out of the unit to a destination unknown. Prediction=> 0
# Gets a signal when other Verizon phones won't. Prediction=> 0
# I love this cable - it allows me to connect any mini-USB device to my PC. Prediction=> 1
# Tasted like dirt. Prediction=> 0
# Magical Help. Prediction=> 0
# Great Value. Prediction=> 1
# !....THE OWNERS REALLY REALLY need to quit being soooooo cheap let them wrap my freaking sandwich in two papers not one! Prediction=> 0
# very slow at seating even with reservation. Prediction=> 0
# The acting was decidely wooden, though no worse than a period Universal B movie.   Prediction=> 0
# The chipolte ranch dipping sause was tasteless, seemed thin and watered down with no heat. Prediction=> 0
# Very happy with this product. Prediction=> 1
# The vanilla ice cream was creamy and smooth while the profiterole (choux) pastry was fresh enough. Prediction=> 1
# You'll love it!  	1
# This movie is BAD.  	0
# So bad.  	0
# The film is way too long.  	0
# This is definitely one of the bad ones.  	0
# The movie I received was a great quality film for it's age.  	1
# John Wayne did an incredible job for being so young in the movie industry.  	1
# His on screen presence shined thought even though there were other senior actors on the screen with him.  	1
# I think that it is a must see older John Wayne film.  	1
# I really don't see how anyone could enjoy this movie.  	0
# I don't think I've ever seen a movie half as boring as this self-indulgent piece of junk.  	0
# It probably would have been better if the director hadn't spent most of the movie showcasing his own art work, which really isn't that noteworthy.  	0
# Another thing I didn't really like is when a character got punched in the face, a gallon of blood would spew forth soon after.  	0
# Jamie Foxx absolutely IS Ray Charles.  	1
# His performance is simply genius.  	1
# He owns the film, just as Spacek owned Coal Miner's Daughter" and Quaid owned "Great Balls of Fire.   Prediction=> 1
# I ordered the Voodoo pasta and it was the first time I'd had really excellent pasta since going gluten free several years ago. Prediction=> 0
# It's a long time since I was so entertained by a movie.   Prediction=> 0
# It's as continuously beautiful to look at as a Bertolucci, but the relationships here are more convincing and the narrative more engaging than some of that master's work.   Prediction=> 0
# If she had not rolled the eyes we may have stayed... Not sure if we will go back and try it again. Prediction=> 0
# This is essentially a communications tool that does not communicate. Prediction=> 0
# This is a great deal. Prediction=> 1
# A pretty good product. Prediction=> 1
# Our server was fantastic and when he found out the wife loves roasted garlic and bone marrow, he added extra to our meal and another marrow to go! Prediction=> 1
# The bus boy on the other hand was so rude. Prediction=> 0
# All in all, I'd expected a better consumer experience from Motorola. Prediction=> 1
# Bluetooth does not work, phone locks up, screens just flash up and now it just makes calls randomly while in my pocket locked. Prediction=> 0
# Not good for the money. Prediction=> 1
# Battery lasts only a few hours. Prediction=> 0
# I have been in more than a few bars in Vegas, and do not ever recall being charged for tap water. Prediction=> 1
# This place has a lot of promise but fails to deliver. Prediction=> 1
# Every single character was hilarious and deserved to be called a lead.   Prediction=> 1
# This product is ideal for people like me whose ears are very sensitive. Prediction=> 1
# We ordered some old classics and some new dishes after going there a few times and were sorely disappointed with everything. Prediction=> 0
# We literally sat there for 20 minutes with no one asking to take our order. Prediction=> 0

# %%
# Accuracy
print("Train Accuracy: ",pipe.score(X_train,y_train))
print("Test Accuracy: ",pipe.score(X_test,y_test))
# Out:
# Train Accuracy:  0.9872611464968153
# Test Accuracy:  0.7509090909090909

# %%
# Another random review
pipe.predict(["This was a great movie"])
# Out:
# array([1], dtype=int64)

# %%
example = ["I do enjoy my job",
 "What a poor product!,I will have to get a new one",
 "I feel amazing!"]

# %%
pipe.predict(example)
# Out:
# array([1, 0, 1], dtype=int64)

# %%
#### Using Tfid

# %%
# Create the  pipeline to clean, tokenize, vectorize, and classify 
pipe_tfid = Pipeline([("cleaner", predictors()),
                 ('vectorizer', tfvectorizer),
                 ('classifier', classifier)])

# %%
pipe_tfid.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('cleaner', <__main__.predictors object at 0x000001DDC84238B0>),
#                 ('vectorizer',
#                  TfidfVectorizer(tokenizer=<function spacy_tokenizer at 0x000001DDC00D0E50>)),
#                 ('classifier', LinearSVC())])

# %%
sample_prediction1 = pipe_tfid.predict(X_test)

# %%
for (sample,pred) in zip(X_test,sample_prediction1):
    print(sample,"Prediction=>", pred)
# Out:
# Great product. Prediction=> 1
# This product is very High quality Chinese CRAP!!!!!! Prediction=> 0
# Let's start with all the problemsthe acting, especially from the lead professor, was very, very bad.   Prediction=> 0
# It's too bad that everyone else involved didn't share Crowe's level of dedication to quality, for if they did, we'd have a far better film on our hands than this sub-par mess.   Prediction=> 0
# It always cuts out and makes a beep beep beep sound then says signal failed. Prediction=> 0
# Generous portions and great taste. Prediction=> 1
# Whatever prompted such a documentary is beyond me!   Prediction=> 0
# This phone might well be the worst I've ever had in any brand. Prediction=> 0
# Went for lunch - service was slow. Prediction=> 0
# Also, the fries are without a doubt the worst fries I've ever had. Prediction=> 0
# The refried beans that came with my meal were dried out and crusty and the food was bland. Prediction=> 0
# The only possible way this movie could be redeemed would be as MST3K fodder.   Prediction=> 0
# Bland and flavorless is a good way of describing the barely tepid meat. Prediction=> 0
# Service was exceptional and food was a good as all the reviews. Prediction=> 1
# Was not happy. Prediction=> 1
# You get what you pay for I guess. Prediction=> 0
# Be sure to order dessert, even if you need to pack it to-go - the tiramisu and cannoli are both to die for. Prediction=> 1
# I still maintain that monkeys shouldn't make headphones, we just obviously don't share enough DNA to copy the design over to humans. Prediction=> 0
# Everyone is very attentive, providing excellent customer service. Prediction=> 1
# To be honest with you, this is unbelievable nonsense and very foolish.   Prediction=> 0
# Not a good item.. It worked for a while then started having problems in my auto reverse tape player. Prediction=> 0
# I'm not really sure how Joey's was voted best hot dog in the Valley by readers of Phoenix Magazine. Prediction=> 1
# Very poor service. Prediction=> 0
# sucked, most of the stuff does not work with my phone. Prediction=> 0
# In short - this was a monumental waste of time and energy and I would not recommend anyone to EVER see this film.   Prediction=> 0
# You also cannot take pictures with it in the case because the lense is covered. Prediction=> 1
# If you're not familiar, check it out. Prediction=> 1
# Mic Doesn't work. Prediction=> 0
# The food came out at a good pace. Prediction=> 0
# Ordered a double cheeseburger & got a single patty that was falling apart (picture uploaded) Yeah, still sucks. Prediction=> 0
# Well packaged, arrived on time, and works as intended. Prediction=> 1
# I liked it.   Prediction=> 1
# I probably won't be coming back here. Prediction=> 0
# The ambiance here did not feel like a buffet setting, but more of a douchey indoor garden for tea and biscuits. Prediction=> 0
# It felt like a very gripping, intelligent stage play (but without the overly theatrical feeling one actually gets from watching people on a stage) which plays on everyone's terror of a white lie escalating to monstrous consequences.   Prediction=> 1
# Hayao Miyazaki's latest and eighth film for Studio Ghibili, "Gake No Ue No Ponyo" (Ponyo on the Cliff by the Sea) is a wonderfully fun and imaginative look at childhood.   Prediction=> 1
# Come hungry, leave happy and stuffed! Prediction=> 1
# Just does not work. Prediction=> 0
# I find wasting food to be despicable, but this just wasn't food. Prediction=> 0
# I could not recommend these more. Prediction=> 1
# This is an extraordinary film.   Prediction=> 1
# The fried rice was dry as well. Prediction=> 0
# The sets (especially designed to work with the camera) are amazing....stylized, beautiful and effective.   Prediction=> 1
# My brother in law who works at the mall ate here same day, and guess what he was sick all night too. Prediction=> 1
# So Far So Good!. Prediction=> 1
# End of Days is one of the worst big-budget action movies I've ever seen.   Prediction=> 0
# Pretty piece of junk. Prediction=> 0
# The food is about on par with Denny's, which is to say, not good at all. Prediction=> 0
# I found this place by accident and I could not be happier. Prediction=> 1
# The update procedure is difficult and cumbersome. Prediction=> 0
# Waste of money. Prediction=> 0
# I vomited in the bathroom mid lunch. Prediction=> 0
# Nine out of ten for a truly lovely film.   Prediction=> 1
# It would take too long to describe how bad my customer service experience has been with Amazon. Prediction=> 0
# The movie has almost no action scenes in it and very little comedy.   Prediction=> 1
# Weird vibe from owners. Prediction=> 1
# This was my first time and I can't wait until the next. Prediction=> 1
# And the drinks are WEAK, people! Prediction=> 0
# The "explosion" of the Gas tanks at the end was just as awful.   Prediction=> 0
# $50 Down the drain. Prediction=> 0
# Reaching for the bottom row is uncomfortable, and the send and end keys are not where I expect them to be.3. Prediction=> 0
# With the originality and freshness of the first movie now spent, this remake had little else to offer.   Prediction=> 0
# For about 10 minutes, we we're waiting for her salad when we realized that it wasn't coming any time soon. Prediction=> 0
# It was way over fried. Prediction=> 0
# I don't think we'll be going back anytime soon. Prediction=> 0
# And generally the lines and plot is weaker than the average episode.   Prediction=> 0
# Again, no plot at all.   Prediction=> 0
# Not a good bargain. Prediction=> 1
# Before I go in to why I gave a 1 star rating please know that this was my third time eating at Bachi burger before writing a review. Prediction=> 0
# The script iswas there a script?   Prediction=> 0
# The case is great and works fine with the 680. Prediction=> 1
# In fact I'm going to round up to 4 stars, just because she was so awesome. Prediction=> 1
# It is cheap, and it feel and look just as cheap. Prediction=> 0
# Director Neil LaBute uses brutal violence to seperate dreams from reality, and along with the touching drama, and hilarious comedy, you can never tell what is going to happen next.   Prediction=> 0
# As many people complained, I found this headset's microphone was very weak. Prediction=> 1
# No ear loop needed, it's tiny and the sound is great. Prediction=> 1
# You can not answer calls with the unit, never worked once! Prediction=> 0
# Yes, I am simplifying things here for the sake of brevity, for this really is at the core of the problems with this film - it has too much going on without any real, fulfilling explanation.   Prediction=> 0
# Overall, I would recommend this phone over the new Walkman. Prediction=> 1
# Perhaps I caught them on an off night judging by the other reviews, but I'm not inspired to go back. Prediction=> 1
# Perfect for someone (me) who only likes beer ice cold, or in this case, even colder. Prediction=> 1
# Not a single employee came out to see if we were OK or even needed a water refill once they finally served us our food. Prediction=> 0
# For the price on Amazon, it is an excellent product, which I would highly recommend. Prediction=> 1
# Piece of Junk. Prediction=> 0
# I saw it as a child on TV back in 1973, when it was "The Stranger" and I loved it.   Prediction=> 1
# Also, it's a real treat to see Anthony Quinn playing Crazy Horse.   Prediction=> 1
# Mediocre food. Prediction=> 0
# Im big fan of RPG games too, but this movie, its a disgrace to any self-respecting RPGer there is.   Prediction=> 0
# The best place in Vegas for breakfast (just check out a Sat, or Sun. Prediction=> 1
# I really loved the story line and the poler bear was kinda cute.But if anyone has a question about Fort Steele, just ask away:)   Prediction=> 1
# Waited and waited and waited. Prediction=> 0
# I liked the way Dustin Hoffman's character was ready to do just about everything to stay with his son.   Prediction=> 1
# Despite how hard I rate businesses, its actually rare for me to give a 1 star. Prediction=> 0
# Every time he opened his mouth you expect to hear, "you see kids..." Pulling the plug was a mercy killing for this horrible show.   Prediction=> 0
# It took over 30 min to get their milkshake, which was nothing more than chocolate milk. Prediction=> 0
# This is the phone to get for 2005.... I just bought my S710a and all I can say is WOW! Prediction=> 0
# Their rotating beers on tap is also a highlight of this place. Prediction=> 1
# It quit working after I'd used it for about 18 months, so I just purchased another one because this is the best headset I've ever owned. Prediction=> 1
# Despite the pans of reviewers, I liked this movie.   Prediction=> 1
# The best example of how dumb the writing is when it's established that you can turn the zombie-students back into humans by removing a necklace containing a piece of the meteorite.   Prediction=> 0
# The rest of the movie lacks art, charm, meaning... If it's about emptiness, it works I guess because it's empty.   Prediction=> 1
# Yes it's shiny on front side - and I love it! Prediction=> 1
# Appears to actually outperform the original battery from China that came with my V325i. Prediction=> 1
# too bad cause I know it's family owned, I really wanted to like this place. Prediction=> 0
# Hot dishes are not hot, cold dishes are close to room temp.I watched staff prepare food with BARE HANDS, no gloves.Everything is deep fried in oil. Prediction=> 0
# Emily Watson's character is very strong, and she has only to give a quick glance and you understand everything.   Prediction=> 1
# The headsets are easy to use and everyone loves them. Prediction=> 1
# Favorite place in town for shawarrrrrrma!!!!!! Prediction=> 1
# This place should honestly be blown up. Prediction=> 0
# Coming here is like experiencing an underwhelming relationship where both parties can't wait for the other person to ask to break up. Prediction=> 0
# I LOVED it! Prediction=> 1
# I waited and waited. Prediction=> 0
# The waiter wasn't helpful or friendly and rarely checked on us. Prediction=> 1
# Please dont waste your money. Prediction=> 0
# Unfortunately, inexperience of direction meant that scene after scene passed with little in the way of dramatic tension or conflict.   Prediction=> 0
# I'll put this gem up against any movie in terms of screenplay, cinematography, acting, post-production, editing, directing, or any other aspect of film-making.   Prediction=> 0
# Don't bother - go to the store. Prediction=> 0
# Thoroughly disappointed! Prediction=> 0
# The characters are fleshed out surprisingly well, particularly Grimes and Blake, and all the actors deliver their sharply scripted lines with just the right amount of deadpan tongue in cheek to make the dialogue both hilarious and realistic.   Prediction=> 0
# The best electronics of the available FM Transmitters. Prediction=> 1
# While you don't yet hear Mickey speak, there are tons of sound effects and music throughout the film--something we take for granted now but which was a huge crowd pleaser in 1928.   Prediction=> 0
# Basically the service was very bad. Prediction=> 0
# The manager was the worst. Prediction=> 0
# I'm terribly disappointed that this film would receive so many awards and accolades, especially when there are far more deserving works of film out there.   Prediction=> 1
# I love this phone!. Prediction=> 1
# The directing seems too pretentious.   Prediction=> 0
# The opening sequence of this gem is a classic, and the cat n mouse games that follow are a delight to watch.   Prediction=> 1
# I am more than happy with this product. Prediction=> 1
# The movie was very interesting from beginning to the end.   Prediction=> 1
# Gets the job done. Prediction=> 1
# The calls drop, the phone comes on and off at will, the screen goes black and the worst of all it stops ringing intermittently. Prediction=> 0
# If you like a loud buzzing to override all your conversations, then this phone is for you! Prediction=> 0
# Final Word: This Show is a real torture!!   Prediction=> 0
# Frozen pucks of disgust, with some of the worst people behind the register. Prediction=> 0
# As for the service, I thought it was good. Prediction=> 1
# The nokia CA-42 USB cable did not work with my phone. Prediction=> 0
# But "Tiny Toons" kept the 90's vibe and delivered one of the most popular, funny, and underrated cartoons ever created.   Prediction=> 1
# This isn't a small family restaurant, this is a fine dining establishment. Prediction=> 1
# I rather enjoyed it.   Prediction=> 1
# Food was delicious! Prediction=> 1
# Also makes it easier to hold on to. Prediction=> 0
# Best breakfast buffet!!! Prediction=> 1
# It is light, has plenty of battery capacity, and is very confortable to wear for somewhat extended periods of time. Prediction=> 1
# You won't regret it! Prediction=> 1
# My gyro was basically lettuce only. Prediction=> 0
# The live music on Fridays totally blows. Prediction=> 0
# The place was not clean and the food oh so stale! Prediction=> 0
# The battery works great! Prediction=> 1
# Customer service was terrible. Prediction=> 0
# Worst Customer Service Ever. Prediction=> 0
# John Garfield, Ann revere, Lilli Plmer, William Conrad, Canada Lee...and filmed by one of the greatest cinematographers to ever grace the screen..James Wong Howe.   Prediction=> 1
# This is a stunning movie.   Prediction=> 0
# The best scene in the movie was when Gerardo is trying to find a song that keeps running through his head.   Prediction=> 1
# The things that the four kids get themselves into is absolutely hilarious to watch.   Prediction=> 0
# Dont waste your money... Prediction=> 0
# The Jabra EarGels fit my ears very well. Prediction=> 1
# This is one of the worst Sandra Bullock movie since Speed 2 But not quite that bad.   Prediction=> 0
# Would come back again if I had a sushi craving while in Vegas. Prediction=> 1
# If you like a loud buzzing to override all your conversations, then this phone is for you! Prediction=> 0
# Talk about USELESS customer service. Prediction=> 0
# We had a group of 70+ when we claimed we would only have 40 and they handled us beautifully. Prediction=> 0
# There is no plot here to keep you going in the first place.   Prediction=> 0
# 10/10   Prediction=> 1
# Horrible, horrible protector. Prediction=> 0
# The deal included 5 tastings and 2 drinks, and Jeff went above and beyond what we expected. Prediction=> 0
# Then, as if I hadn't wasted enough of my life there, they poured salt in the wound by drawing out the time it took to bring the check. Prediction=> 0
# MANNA FROM HEAVEN is a terrific film that is both predictable and unpredictable at the same time.   Prediction=> 1
# Not a weekly haunt, but definitely a place to come back to every once in a while. Prediction=> 1
# The Heart Attack Grill in downtown Vegas is an absolutely flat-lined excuse for a restaurant. Prediction=> 0
# The results, well, are a shame.   Prediction=> 0
# And considering the two of us left there very full and happy for about $20, you just can't go wrong. Prediction=> 0
# A very, very, very slow-moving, aimless movie about a distressed, drifting young man.   Prediction=> 0
# VERY DISAPPOINTED. Prediction=> 0
# The cutouts and buttons are placed perfectly. Prediction=> 0
# Would not reccommend. Prediction=> 0
# Very Dissapointing Performance. Prediction=> 1
# Judith Light is one of my favorite actresses and I think she does a superb job in this film!   Prediction=> 1
# I will never go back to this place and will never ever recommended this place to anyone! Prediction=> 0
# Could not get strong enough signal. Prediction=> 0
# AN HOUR... seriously? Prediction=> 0
# We thought you'd have to venture further away to get good sushi, but this place really hit the spot that night. Prediction=> 1
# The charger arrived within the promised timeframe, but it did not work. Prediction=> 0
# The text messaging feature is really tricky to use. Prediction=> 1
# The fat computer geek was unbelievable, the bible thumper, the bad-ass girl, who are these actors???   Prediction=> 0
# The food was very good and I enjoyed every mouthful, an enjoyable relaxed venue for couples small family groups etc. Prediction=> 1
# Five star Plus, plus. Prediction=> 1
# I also didn't like the "on" button, it felt like it would crack with use. Prediction=> 0
# Well... Just if you keep thinking how bad it is.   Prediction=> 0
# Overall I wasn't very impressed with Noca. Prediction=> 0
# The cast of veteran actors are more than just a nostalgia trip.   Prediction=> 1
# It's a great place and I highly recommend it. Prediction=> 1
# She carries the movie well.   Prediction=> 1
# Some applause should be given to the "prelude" however.   Prediction=> 1
# I won't try going back there even if it's empty. Prediction=> 0
# I am so tired of clichés that is just lazy writing, and here they come in thick and fast.   Prediction=> 1
# And, FINALLY, after all that, we get to an ending that would've been great had it been handled by competent people and not Jerry Falwell.   Prediction=> 1
# I received it quickly and it works great!! Prediction=> 1
# The phone loads super! Prediction=> 0
# No, I'm going to eat the potato that I found some strangers hair in it. Prediction=> 0
# I had the chicken Pho and it tasted very bland. Prediction=> 0
# The screen does get smudged easily because it touches your ear and face. Prediction=> 0
# All the pretty pictures in the world cannot make up for a piece of work that is flawed at the core.   Prediction=> 0
# I have tried these cables with my computer and my iPod and it works just fine. Prediction=> 1
# Not only will it drain your player, but may also potentially fry it. Prediction=> 0
# Don't waste your money!. Prediction=> 0
# From what my dinner companions told me...everything was very fresh with nice texture and taste. Prediction=> 1
# The only thing I did like was the prime rib and dessert section. Prediction=> 0
# The owners are super friendly and the staff is courteous. Prediction=> 1
# Logitech Bluetooth Headset is a 10!. Prediction=> 1
# This is a good battery, and it got here really fast. Prediction=> 1
# The least said about the acting the better.   Prediction=> 1
# They refuse to refund or replace. Prediction=> 1
# We'd definitely go back here again. Prediction=> 1
# An excellent performance from Ms.   Prediction=> 1
# This item worked great, but it broke after 6 months of use. Prediction=> 1
# I do love sushi, but I found Kabuki to be over-priced, over-hip and under-services. Prediction=> 1
# Never again will I be dining at this place! Prediction=> 1
# Don't buy this product. Prediction=> 0
# Service was fantastic. Prediction=> 1
# I agree with Jessica, this movie is pretty bad.   Prediction=> 0
# It was so BORING!   Prediction=> 0
# The chips that came out were dripping with grease, and mostly not edible. Prediction=> 0
# She was quite disappointed although some blame needs to be placed at her door. Prediction=> 0
# Having to humour him just to get by and get through the day was so apt.   Prediction=> 0
# The range is very decent, I've been able to roam around my house with the phone in the living room with no reception/sound quality issues. Prediction=> 1
# WELL IM SATISFIED. Prediction=> 1
# I've tried several different earpieces for my cell phone and this Jabra one is the first one I've found that fits my ear comfortably. Prediction=> 1
# And then tragedy struck. Prediction=> 0
# Not recommended.   Prediction=> 1
# No shifting, no bubbling, no peeling, not even a scratch, NOTHING!I couldn't be more happier with my new one for the Droid. Prediction=> 1
# Great Product. Prediction=> 1
# The worst was the salmon sashimi. Prediction=> 0
# Linked to my phone without effort. Prediction=> 0
# Lange had become a great actress.   Prediction=> 1
# Works great. Prediction=> 1
# nice leather. Prediction=> 1
# fast service. Prediction=> 1
# You need two hands to operate the screen.This software interface is decade old and cannot compete with new software designs. Prediction=> 1
# Food is way overpriced and portions are fucking small. Prediction=> 0
# It has northern humour and positive about the community it represents.   Prediction=> 0
# What I really like there is the crepe station. Prediction=> 1
# Never heard of any of them except Cole who was totally unbelievable in the part.   Prediction=> 0
# We also ordered the spinach and avocado salad; the ingredients were sad and the dressing literally had zero taste. Prediction=> 0
# horrible, had to switch 3 times. Prediction=> 0
# Rip off---- Over charge shipping. Prediction=> 1
# On a positive note, our server was very attentive and provided great service. Prediction=> 1
# All I have to say is the food was amazing!!! Prediction=> 1
# Definitely not worth the $3 I paid. Prediction=> 0
# But when I check voice mail at night, the keypad backlight turns off a few seconds into the first message, and then I'm lost. Prediction=> 1
# But this movie is definitely a below average rent.   Prediction=> 0
# I don't have very many words to say about this place, but it does everything pretty well. Prediction=> 1
# Both do good jobs and are quite amusing.   Prediction=> 1
# Still, it makes up for all of this with a super ending that depicts a great sea vessel being taken out by the mighty frost.   Prediction=> 1
# I think this restaurant suffers from not trying hard enough. Prediction=> 0
# One of the most boring,pointless movies I have ever seen.   Prediction=> 0
# Great choice! Prediction=> 1
# I am sorry I made this purchase. Prediction=> 0
# A FLY was in my apple juice.. A FLY!!!!!!!! Prediction=> 1
# The acting was bad, the dialogs were extremely shallow and insincere.   Prediction=> 0
# Bad Purchase. Prediction=> 0
# We watched our waiter pay a lot more attention to other tables and ignore us. Prediction=> 0
# I have watched their prices inflate, portions get smaller and management attitudes grow rapidly! Prediction=> 0
# And the accents are absolutely abysmal!   Prediction=> 1
# It was delicious!!! Prediction=> 1
# An interesting premise, and Billy Drago is always good as a dangerous nut-bag (side note: I'd love to see Drago, Stephen McHattie and Lance Hendrikson in a flick together; talk about raging cheekbones!).   Prediction=> 1
# This phone is slim and light and the display is beautiful. Prediction=> 1
# After a year the battery went completely dead on my headset. Prediction=> 0
# Delicious NYC bagels, good selections of cream cheese, real Lox with capers even. Prediction=> 1
# The feel of the dining room was more college cooking course than high class dining and the service was slow at best. Prediction=> 1
# This place deserves no stars. Prediction=> 1
# I bought this battery with a coupon from Amazon and I'm very happy with my purchase. Prediction=> 0
# Over rated. Prediction=> 0
# The warmth it generates is in contrast to its austere backdrop.   Prediction=> 0
# 20th Century Fox's ROAD HOUSE 1948) is not only quite a silly noir but is an implausible unmitigated bore of a movie.   Prediction=> 0
# Totally different, with loads of understatement and black comedy, this is a film few get to see, but those who do will remember it.   Prediction=> 0
# It is a true classic.   Prediction=> 1
# Plus, it was well-paced and suited its relatively short run time.   Prediction=> 1
# The service was a bit lacking. Prediction=> 0
# The film deserves strong kudos for taking this stand, for having exceptional acting from its mostly lesser-known cast and for the super-intelligent script that doesn't insult the audience or take the easy way out when it comes to white racism.   Prediction=> 1
# Definitely worth checking out.   Prediction=> 1
# He is almost unbearable to watch on screen, he has little to no charisma, and terrible comedic timing.   Prediction=> 0
# Lordy, the Khao Soi is a dish that is not to be missed for curry lovers! Prediction=> 0
# Just whatever you do, avoid "Groove" as its the antithesis of all that is good about Human Traffic.   Prediction=> 0
# Arrived quickly and much less expensive than others being sold. Prediction=> 0
# Very nice and relaxing late night viewing.   Prediction=> 1
# Great product and price. Prediction=> 1
# I never come again. Prediction=> 1
# We waited for forty five minutes in vain. Prediction=> 0
# This place deserves one star and 90% has to do with the food. Prediction=> 0
# I use this product in a motor control center where there is a lot of high voltage humming from the equipment, and it works great! Prediction=> 1
# The Veggitarian platter is out of this world! Prediction=> 1
# .... Item arrived quickly and works great with my Metro PCS Samsung SCH-r450 slider phone and Sony Premium Sound in ear plugs. Prediction=> 1
# Then I watched it again two Sundays ago (March 20th, 2005) and I began to really enjoy it and this time I taped the entire thing.   Prediction=> 1
# It really created a unique feeling though.   Prediction=> 0
# Krussel Always good. Prediction=> 1
# Nice case, feels good in your hands. Prediction=> 1
# We walked away stuffed and happy about our first Vegas buffet experience. Prediction=> 1
# I'm so happy to be here!!!" Prediction=> 1
# I posted more detailed comments under the grey or black phone, but i have the Fire Red and it's a great color! Prediction=> 1
# I as well would've given godfathers zero stars if possible. Prediction=> 0
# After 3 months, screen just went black all of a sudden. Prediction=> 1
# What is even more stupid is that who had thought an idea that there should be a volcano in Los Angeles?   Prediction=> 0
# I don't think I've ever gone to a movie and disliked it as much.   Prediction=> 0
# The inside is really quite nice and very clean. Prediction=> 1
# Now the pizza itself was good the peanut sauce was very tasty. Prediction=> 1
# When I placed my treo into the case, not only was it NOT snug, but there was A LOT of extra room on the sides. Prediction=> 1
# Doesn't work at all.. I bougth it for my L7c and its not working. Prediction=> 1
# I love this device. Prediction=> 1
# I've never been treated so bad. Prediction=> 0
# Battery is holding up well. Prediction=> 0
# The construction of the headsets is poor. Prediction=> 0
# Just don't know why they were so slow. Prediction=> 0
# The movie is not completely perfect but 'Titta Di Girolamo' will stay with you for a long time after the vision of the movie.   Prediction=> 0
# I don't have to be an accountant to know I'm getting screwed! Prediction=> 1
# Great Subway, in fact it's so good when you come here every other Subway will not meet your expectations. Prediction=> 1
# I recently tried Caballero's and I have been back every week since! Prediction=> 0
# I want my money back. Prediction=> 0
# But in terms of the writing it's very fresh and bold.   Prediction=> 0
# Not frightening in the least, and barely comprehensible.   Prediction=> 0
# Waste of 13 bucks. Prediction=> 0
# An extensive menu provides lots of options for breakfast. Prediction=> 1
# It's been my choice headset for years.Great sound; good volume; good noise cancellation. Prediction=> 1
# His acting alongside Olivia De Havilland was brilliant and the ending was fantastic!   Prediction=> 1
# Warning - Stay away. Prediction=> 0
# This film offers many delights and surprises.   Prediction=> 0
# I recently had problems where I could not stay connected for more than 10 minutes before being disconnected. Prediction=> 0
# If that bug never showed up I would have given a 4 for sure, but on the other side of the wall where this bug was climbing was the kitchen. Prediction=> 1
# During several different 2 minute calls, I experienced 5 drops and it was in an area that had 5 bars. Prediction=> 0
# I bought this to use with my Kindle Fire and absolutely loved it! Prediction=> 1
# definitely will come back here again. Prediction=> 1
# Also notable is John Bailey's fine crisp beautifully colored cinematography and the great production design & costumes by Eiko Ishioka who went on to do the memorable costumes for Coppola's Dracula for which she received a well deserved Oscar.   Prediction=> 1
# Voice Quality, Signal Strength, Dropped Calls. Prediction=> 0
# This was one of the worst films i have ever seen.   Prediction=> 0
# Gave up trying to eat any of the crust (teeth still sore). Prediction=> 0
# The staff are great, the ambiance is great. Prediction=> 1
# But despite these few flaws, this case is of exceptional quality and well worth the additional costs of owning an official OEM product. Prediction=> 0
# One of my favorite purchases ever. Prediction=> 1
# Headset works great & was packaged nicely to avoid any damage. Prediction=> 1
# Highly recommend for any one who has a blue tooth phone. Prediction=> 1
# These are fabulous! Prediction=> 1
# We had fantastic service, and were pleased by the atmosphere. Prediction=> 1
# Lifetime does not air it enough, so if anyone knows what store sells it let me know because this is a must-have.   Prediction=> 0
# Nice design and quality. Prediction=> 1
# 10/10   Prediction=> 1
# If this premise sound stupid, that's because it is.   Prediction=> 0
# The chips and sals a here is amazing!!!!!!!!!!!!!!!!!!! Prediction=> 1
# The service was poor and thats being nice. Prediction=> 1
# If you do go see this movie, bring a pillow or a girlfriend/boyfriend to keep you occupied through out.   Prediction=> 1
# Food was really good and I got full petty fast. Prediction=> 1
# It is worth the drive. Prediction=> 0
# Disappointed!. Prediction=> 0
# However, this didn't make up for the fact that overall, this was a tremendously boring movie.   Prediction=> 1
# I hate to disagree with my fellow Yelpers, but my husband and I were so disappointed with this place. Prediction=> 0
# Seriously flavorful delights, folks. Prediction=> 0
# Very Displeased. Prediction=> 0
# At a time when it seems that film animation has been dominated by Disney/Pixar's CGI masterpieces, it is both refreshing and comforting to know that Miyazaki is still relying on traditional hand-drawn animation to tell his charming and enchanting stories.   Prediction=> 0
# Also the area where my unit broke).- I'm not too fond of the magnetic strap. Prediction=> 0
# Terrible phone holder. Prediction=> 0
# I don't know what kind it is but they have the best iced tea. Prediction=> 1
# The visual effects were AWFUL.   Prediction=> 0
# Overall, a delight!   Prediction=> 1
# Not a pleasant voyage of self-discovery.   Prediction=> 0
# Enough can not be said of the remarkable animation in this film.   Prediction=> 0
# The worst phone I've ever had.... Only had it for a few months. Prediction=> 0
# The one down note is the ventilation could use some upgrading. Prediction=> 0
# Im in AZ all the time and now have my new spot. Prediction=> 1
# This scene is very strong and unpleasant.   Prediction=> 1
# All the other cases I've tried normally fall apart after a few months but this one seems to be in for the long haul. Prediction=> 1
# When Achille and Philippa beautifully sing a duet from "Don Giovanni" that perfectly describes their situation in the movie, you appreciate the subtle layers of this excellent film.   Prediction=> 1
# Elias Koteas,Jack Palance play good roles Angelina is hot and gets naked.Billy Drago appears in this and is cool as usual + a cameo by Sven ole Thorsen helps make this a very enjoyable movie with good acting and a decent budget.   Prediction=> 1
# This is one of the better buffets that I have been to. Prediction=> 1
# I Was Hoping for More. Prediction=> 0
# Vivian Schilling did an excellent job with the script.   Prediction=> 1
# Better Than New. Prediction=> 1
# If you love authentic Mexican food and want a whole bunch of interesting, yet delicious meats to choose from, you need to try this place. Prediction=> 1
# Ordered an appetizer and took 40 minutes and then the pizza another 10 minutes. Prediction=> 0
# Does not fit. Prediction=> 0
# This is an unbelievable BARGAIN! Prediction=> 0
# If the food isn't bad enough for you, then enjoy dealing with the world's worst/annoying drunk people. Prediction=> 0
# It was very popular when I was in the cinema, a good house and very good reactions and plenty of laughs.   Prediction=> 1
# Service was slow and not attentive. Prediction=> 0
# At least 40min passed in between us ordering and the food arriving, and it wasn't that busy. Prediction=> 0
# He came running after us when he realized my husband had left his sunglasses on the table. Prediction=> 0
# I can't see how this movie can be an inspiration to anyone to come out or overcome fear and rejection.   Prediction=> 0
# Total brunch fail. Prediction=> 0
# Victor McLaglen was even bad, and Brian DonLevy was almost unrecognizable.   Prediction=> 0
# Simple, lightweight and great fit. Prediction=> 1
# Nargile - I think you are great. Prediction=> 1
# Furthermore, you can't even find hours of operation on the website! Prediction=> 0
# Service is quick and friendly. Prediction=> 1
# I have seen many movies starring Jaclyn Smith, but my god this was one of her best, though it came out 12 years ago.   Prediction=> 0
# After charging overnight, these batteries work great. Prediction=> 1
# Aside from it's terrible lead, this film has loads of other debits.   Prediction=> 0
# However, my recent experience at this particular location was not so good. Prediction=> 1
# Echo Problem....Very unsatisfactory Prediction=> 0
# I paid too much.   Prediction=> 0
# The design might be ergonomic in theory but I could not stand having these in my ear. Prediction=> 0
# The result is a film that just don't look right.   Prediction=> 1
# Constantine gives everything the right intensity and seems to have a good understanding of the underlying psychological motivations.   Prediction=> 1
# My friend loved the salmon tartar. Prediction=> 1
# The BT headset was such a disapoinment. Prediction=> 1
# Del Taco is pretty nasty and should be avoided if possible. Prediction=> 0
# I enjoyed it.   Prediction=> 1
# I kept catching the cable on the seat and I had to pull the phone out to turn it on an off. Prediction=> 1
# Never going back. Prediction=> 0
# I give Wirefly 1 star.I will contact Cingular/AT&T; and inform them of this practice. Prediction=> 0
# Join the club and get awesome offers via email. Prediction=> 1
# The whole experience was underwhelming, and I think we'll just go to Ninja Sushi next time. Prediction=> 0
# Its not user friendly. Prediction=> 1
# If someone orders two tacos don't' you think it may be part of customer service to ask if it is combo or ala cart? Prediction=> 1
# Their monster chicken fried steak and eggs is my all time favorite. Prediction=> 0
# Which are small and not worth the price. Prediction=> 1
# Unless you're just out to visually "collect" all extant films of Austen's work, you can skip this one.   Prediction=> 0
# I had to walk out of the theatre for a few minutes just to get some relief!   Prediction=> 0
# It is practically useless and did not add any kind of boost to my reception after I bought it. Prediction=> 0
# This was such an awesome movie that i bought it off of Ebay.   Prediction=> 1
# The headset fulfills my requirements so I am happy with my purchase. Prediction=> 1
# There is really nothing for me at postinos, hope your experience is better Prediction=> 1
# Disappointing experience. Prediction=> 0
# They had a toro tartare with a cavier that was extraordinary and I liked the thinly sliced wagyu with white truffle. Prediction=> 1
# Can't upload ringtones from a third party. Prediction=> 1
# Good show, Samsung. Prediction=> 1
# It's so stupid to have to keep buying new chargers, car chargers, cradles, headphones and car kits every time a new phone comes out. Prediction=> 0
# The plot, such as it is, is so derivative and predictable that the ending is like a mercy killing.   Prediction=> 0
# Not good enough for the price. Prediction=> 1
# I gave it a 10   Prediction=> 1
# The cable looks so thin and flimsy, it is scary. Prediction=> 1
# dont go here. Prediction=> 0
# It also took her forever to bring us the check when we asked for it. Prediction=> 0
# I would have casted her in that role after ready the script.   Prediction=> 0
# Works like a charm; it work the same as the one I got with the phone. Prediction=> 1
# Avoid this one if you can. Prediction=> 0
# See it with your kids if you have a chance--it will open up some amazing dialog about how far race relations have come in the last 50 years.   Prediction=> 1
# Technically, the film is well made with impressive camera-work, solid acting and effective music from Riz Ortolani  particularly good is a recurring unaccompanied female vocal that sounds like it's coming from a distant hill.   Prediction=> 1
# BT50 battery junk!. Prediction=> 0
# Works for me. Prediction=> 1
# Best fish I've ever had in my life! Prediction=> 1
# The incredible soundtrack truly captures the essence of the film.   Prediction=> 1
# You can't beat that. Prediction=> 0
# Oh yeah, and the storyline was pathetic too.   Prediction=> 0
# Best Buffet in town, for the price you cannot beat it. Prediction=> 1
# This movie is so awesome!   Prediction=> 1
# very tough and very short on flavor! Prediction=> 1
# Will be back again! Prediction=> 0
# There is nothing privileged about working/eating there. Prediction=> 1
# No allergy warnings on the menu, and the waitress had absolutely no clue as to which meals did or did not contain peanuts. Prediction=> 1
# I might have gotten a defect, but I would not risk buying it again because of the built quality alone. Prediction=> 0
# disappointing. Prediction=> 0
# Good case, Excellent value. Prediction=> 1
# Not good when wearing a hat or sunglasses. Prediction=> 0
# The staff is super nice and very quick even with the crazy crowds of the downtown juries, lawyers, and court staff. Prediction=> 1
# But the premise of the film was so ridiculous: that the President of the U.S.   Prediction=> 0
# Would not recommend to others. Prediction=> 1
# Bought mainly for the charger, which broke soon after purchasing. Prediction=> 0
# The bottowm line...another worthless, cheap gimmick from Sprint. Prediction=> 0
# Protects the phone on all sides. Prediction=> 0
# I wouldn't recommend buying this product. Prediction=> 0
# I can take a little bad service but the food sucks. Prediction=> 0
# After trying many many handsfree gadgets this is the one that finally works well. Prediction=> 1
# REALLY UGLY. Prediction=> 0
# Do not make the same mistake as me. Prediction=> 0
# Shrimp- When I unwrapped it (I live only 1/2 a mile from Brushfire) it was literally ice cold. Prediction=> 0
# Just reading on the specs alone makes you say WOW. Prediction=> 0
# WORST PHONE EVER. Prediction=> 0
# Anyway, I do not think i will go back there. Prediction=> 0
# I don't know what the big deal is about this place, but I won't be back "ya'all". Prediction=> 0
# This movie contained an all-star cast, and what I loved the most was that it opened my eyes to see other actors who I haven't seen before.   Prediction=> 0
# don't waste your money and time. Prediction=> 0
# The reception has been generally good. Prediction=> 1
# I highly recommend this movie for anyone interested in art, poetry, theater, politics, or Japanese history.   Prediction=> 1
# Doesn't do the job. Prediction=> 1
# Very Very Disappointed ordered the $35 Big Bay Plater. Prediction=> 0
# If you haven't gone here GO NOW! Prediction=> 0
# What a waste. Prediction=> 0
# Of course, the acting is blah.   Prediction=> 1
# This film has no redeeming features.   Prediction=> 1
# They also have the best cheese crisp in town. Prediction=> 1
# I've also had problems with the phone reading the memory card in which I always turn it on and then off again. Prediction=> 0
# Worst customer service. Prediction=> 0
# Att is not clear, sound is very distorted and you have to yell when you talk. Prediction=> 1
# I own 2 of these cases and would order another. Prediction=> 1
# The real killer is the volume, and of course it breaking. Prediction=> 0
# For sushi on the Strip, this is the place to go. Prediction=> 0
# The show would begin with smart ass ed comments to each other that would be totally off the wall and uncalled for.   Prediction=> 0
# Also there are combos like a burger, fries, and beer for 23 which is a decent deal. Prediction=> 0
# I've bought $5 wired headphones that sound better than these. Prediction=> 1
# I guess that nobody at the network that aired this dribble watched it before putting it on.   Prediction=> 0
# The movie in movie situations in the beginning and through the game that is played with her by the "acting coach" are fascinating.   Prediction=> 1
# All three broke within two months of use. Prediction=> 1
# Price is good too. Prediction=> 1
# An excellent new restaurant by an experienced Frenchman. Prediction=> 1
# Nothing special. Prediction=> 1
# Great charger. Prediction=> 1
# Update.....went back for a second time and it was still just as amazing Prediction=> 1
# So I bought about 10 of these and saved alot of money. Prediction=> 0
# I have been very satisfied with this cell phone from day one. Prediction=> 1
# Very, very sad. Prediction=> 0
# The screen size is big, key pad lit well enough, and the camera quality is excellent for a camera phone. Prediction=> 1
# I would have given no star if I was able. Prediction=> 1
# Not nearly as good looking as the AMAZON picture makes it look. Prediction=> 0
# Great price, too! Prediction=> 1
# I'll be drivng along, and my headset starts ringing for no reason. Prediction=> 0
# Funny, clever, hip - just like Pray's previous film, Hype!   Prediction=> 1
# VERY comfortable. Prediction=> 1
# It is easy to turn on and off when you are in the car and the volume controls are quite accessable. Prediction=> 0
# I kept looking at the time and it had soon become 35 minutes, yet still no food. Prediction=> 0
# So far it has worked like a charm. Prediction=> 1
# Everything is appalling.   Prediction=> 0
# It was a huge awkward 1.5lb piece of cow that was 3/4ths gristle and fat. Prediction=> 0
# This is a simple little phone to use, but the breakage is unacceptible. Prediction=> 1
# I'd say that would be the hardest decision... Honestly, all of M's dishes taste how they are supposed to taste (amazing). Prediction=> 1
# I did not expect this to be so good! Prediction=> 1
# very good product, well made. Prediction=> 1
# Sooooo good!! Prediction=> 1
# If you have several dozen or several hundred contacts, then imagine the fun of sending each of them one by one. Prediction=> 0
# Avoid at all cost! Prediction=> 0
# The phone can also take great pictures and even video clips. Prediction=> 1
# The Greek dressing was very creamy and flavorful. Prediction=> 1
# The volume switch rocketed out of the unit to a destination unknown. Prediction=> 0
# Gets a signal when other Verizon phones won't. Prediction=> 0
# I love this cable - it allows me to connect any mini-USB device to my PC. Prediction=> 1
# Tasted like dirt. Prediction=> 0
# Magical Help. Prediction=> 0
# Great Value. Prediction=> 1
# !....THE OWNERS REALLY REALLY need to quit being soooooo cheap let them wrap my freaking sandwich in two papers not one! Prediction=> 0
# very slow at seating even with reservation. Prediction=> 0
# The acting was decidely wooden, though no worse than a period Universal B movie.   Prediction=> 0
# The chipolte ranch dipping sause was tasteless, seemed thin and watered down with no heat. Prediction=> 0
# Very happy with this product. Prediction=> 1
# The vanilla ice cream was creamy and smooth while the profiterole (choux) pastry was fresh enough. Prediction=> 1
# You'll love it!  	1
# This movie is BAD.  	0
# So bad.  	0
# The film is way too long.  	0
# This is definitely one of the bad ones.  	0
# The movie I received was a great quality film for it's age.  	1
# John Wayne did an incredible job for being so young in the movie industry.  	1
# His on screen presence shined thought even though there were other senior actors on the screen with him.  	1
# I think that it is a must see older John Wayne film.  	1
# I really don't see how anyone could enjoy this movie.  	0
# I don't think I've ever seen a movie half as boring as this self-indulgent piece of junk.  	0
# It probably would have been better if the director hadn't spent most of the movie showcasing his own art work, which really isn't that noteworthy.  	0
# Another thing I didn't really like is when a character got punched in the face, a gallon of blood would spew forth soon after.  	0
# Jamie Foxx absolutely IS Ray Charles.  	1
# His performance is simply genius.  	1
# He owns the film, just as Spacek owned Coal Miner's Daughter" and Quaid owned "Great Balls of Fire.   Prediction=> 0
# I ordered the Voodoo pasta and it was the first time I'd had really excellent pasta since going gluten free several years ago. Prediction=> 0
# It's a long time since I was so entertained by a movie.   Prediction=> 0
# It's as continuously beautiful to look at as a Bertolucci, but the relationships here are more convincing and the narrative more engaging than some of that master's work.   Prediction=> 0
# If she had not rolled the eyes we may have stayed... Not sure if we will go back and try it again. Prediction=> 0
# This is essentially a communications tool that does not communicate. Prediction=> 0
# This is a great deal. Prediction=> 1
# A pretty good product. Prediction=> 1
# Our server was fantastic and when he found out the wife loves roasted garlic and bone marrow, he added extra to our meal and another marrow to go! Prediction=> 1
# The bus boy on the other hand was so rude. Prediction=> 0
# All in all, I'd expected a better consumer experience from Motorola. Prediction=> 1
# Bluetooth does not work, phone locks up, screens just flash up and now it just makes calls randomly while in my pocket locked. Prediction=> 0
# Not good for the money. Prediction=> 0
# Battery lasts only a few hours. Prediction=> 0
# I have been in more than a few bars in Vegas, and do not ever recall being charged for tap water. Prediction=> 1
# This place has a lot of promise but fails to deliver. Prediction=> 1
# Every single character was hilarious and deserved to be called a lead.   Prediction=> 1
# This product is ideal for people like me whose ears are very sensitive. Prediction=> 1
# We ordered some old classics and some new dishes after going there a few times and were sorely disappointed with everything. Prediction=> 0
# We literally sat there for 20 minutes with no one asking to take our order. Prediction=> 0

# %%
print("Accuracy: ",pipe_tfid.score(X_test,y_test))
print("Accuracy: ",pipe_tfid.score(X_test,sample_prediction1))
# Out:
# Accuracy:  0.7763636363636364
# Accuracy:  1.0

# %%
### Jesse JCharis
### J-Secur1ty
### Jesus Saves @ JCharisTech
